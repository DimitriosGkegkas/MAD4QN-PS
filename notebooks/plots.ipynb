# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Change the current working directory to the parent directory
os.chdir('..')

# %%
# Fake data for starters 
import shutil

# Define the source files and their corresponding new names with index
base_names = [
    'avg_speed_mad4qn_',
    'collisions_mad4qn_',
    'travel_time_mad4qn_',
    'waiting_time_mad4qn_'
]

# Directory containing the source files
source_directory = 'data/'

# Loop through indices 1 to 9
for index in range(1, 10):
    for base_name in base_names:
        # Construct the new filename
        new_filename = f'{base_name}{index}.npy'
        base_name = f'{base_name}0.npy'
        
        # Full path for source and destination
        src_file = os.path.join(source_directory, base_name)
        dst_file = os.path.join(source_directory, new_filename)
        
        # Copy the file
        shutil.copy(src_file, dst_file)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
# FTTL 1

travel_time_fttl1 = np.load('baselines/travel_time_fttl1_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/travel_time_fttl1_{i}.npy')
    travel_time_fttl1 = np.concatenate((travel_time_fttl1, tmp))
    
waiting_time_fttl1 = np.load('baselines/waiting_time_fttl1_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/waiting_time_fttl1_{i}.npy')
    waiting_time_fttl1 = np.concatenate((waiting_time_fttl1, tmp))
    
avg_speed_fttl1 = np.load('baselines/avg_speed_fttl1_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/avg_speed_fttl1_{i}.npy')
    avg_speed_fttl1 = np.concatenate((avg_speed_fttl1, tmp))
    
# FTTL 2

travel_time_fttl2 = np.load('baselines/travel_time_fttl2_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/travel_time_fttl2_{i}.npy')
    travel_time_fttl2 = np.concatenate((travel_time_fttl2, tmp))
    
waiting_time_fttl2 = np.load('baselines/waiting_time_fttl2_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/waiting_time_fttl2_{i}.npy')
    waiting_time_fttl2 = np.concatenate((waiting_time_fttl2, tmp))
    
avg_speed_fttl2 = np.load('baselines/avg_speed_fttl2_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/avg_speed_fttl2_{i}.npy')
    avg_speed_fttl2 = np.concatenate((avg_speed_fttl2, tmp))
    
# ATL 1

travel_time_atl1 = np.load('baselines/travel_time_atl1_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/travel_time_atl1_{i}.npy')
    travel_time_atl1 = np.concatenate((travel_time_atl1, tmp))
    
waiting_time_atl1 = np.load('baselines/waiting_time_atl1_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/waiting_time_atl1_{i}.npy')
    waiting_time_atl1 = np.concatenate((waiting_time_atl1, tmp))
    
avg_speed_atl1 = np.load('baselines/avg_speed_atl1_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/avg_speed_atl1_{i}.npy')
    avg_speed_atl1 = np.concatenate((avg_speed_atl1, tmp))
    
# ATL 2

travel_time_atl2 = np.load('baselines/travel_time_atl2_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/travel_time_atl2_{i}.npy')
    travel_time_atl2 = np.concatenate((travel_time_atl2, tmp))
    
waiting_time_atl2 = np.load('baselines/waiting_time_atl2_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/waiting_time_atl2_{i}.npy')
    waiting_time_atl2 = np.concatenate((waiting_time_atl2, tmp))
    
avg_speed_atl2 = np.load('baselines/avg_speed_atl2_0.npy')
for i in range(1, 10):
    tmp = np.load(f'baselines/avg_speed_atl2_{i}.npy')
    avg_speed_atl2 = np.concatenate((avg_speed_atl2, tmp))
    
# RANDOM

travel_time_random = np.load('datarandom/travel_time_random_0.npy')
for i in range(1, 10):
    tmp = np.load(f'datarandom/travel_time_random_{i}.npy')
    travel_time_random = np.concatenate((travel_time_random, tmp))
    
waiting_time_random = np.load('datarandom/waiting_time_random_0.npy')
for i in range(1, 10):
    tmp = np.load(f'datarandom/waiting_time_random_{i}.npy')
    waiting_time_random = np.concatenate((waiting_time_random, tmp))
    
avg_speed_random = np.load('datarandom/avg_speed_random_0.npy')
for i in range(1, 10):
    tmp = np.load(f'datarandom/avg_speed_random_{i}.npy')
    avg_speed_random = np.concatenate((avg_speed_random, tmp))
    
collisions_random = np.load('datarandom/collisions_random_0.npy')
for i in range(1, 10):
    tmp = np.load(f'datarandom/collisions_random_{i}.npy')
    collisions_random = np.concatenate((collisions_random, tmp))
    
# MAD4QN-PS

travel_time_mad4qn = np.load('data/travel_time_mad4qn_0.npy')
for i in range(1, 10):
    tmp = np.load(f'data/travel_time_mad4qn_{i}.npy')
    travel_time_mad4qn = np.concatenate((travel_time_mad4qn, tmp))
    
waiting_time_mad4qn = np.load('data/waiting_time_mad4qn_0.npy')
for i in range(1, 10):
    tmp = np.load(f'data/waiting_time_mad4qn_{i}.npy')
    waiting_time_mad4qn = np.concatenate((waiting_time_mad4qn, tmp))
    
avg_speed_mad4qn = np.load('data/avg_speed_mad4qn_0.npy')
for i in range(1, 10):
    tmp = np.load(f'data/avg_speed_mad4qn_{i}.npy')
    avg_speed_mad4qn = np.concatenate((avg_speed_mad4qn, tmp))
    
collisions_mad4qn = np.load('data/collisions_mad4qn_0.npy')
for i in range(1, 10):
    tmp = np.load(f'data/collisions_mad4qn_{i}.npy')
    collisions_mad4qn = np.concatenate((collisions_mad4qn, tmp))

# %%
travel_time_histo = {
    'FTTL2': [np.mean(travel_time_fttl2), np.mean(waiting_time_fttl2)],
    'FTTL1': [np.mean(travel_time_fttl1), np.mean(waiting_time_fttl1)],
    'ATL2': [np.mean(travel_time_atl2), np.mean(waiting_time_atl2)],
    'ATL1': [np.mean(travel_time_atl1), np.mean(waiting_time_atl1)],
    'RP': [np.mean(travel_time_random), np.mean(waiting_time_random)],
    'MAD4QN-PS': [np.mean(travel_time_mad4qn), np.mean(waiting_time_mad4qn)]
}

travel_time_histo2 = {
    'FTTL1': [np.mean(travel_time_fttl1), np.mean(waiting_time_fttl1)],
    'FTTL2': [np.mean(travel_time_fttl2), np.mean(waiting_time_fttl2)],
    'ATL1': [np.mean(travel_time_atl1), np.mean(waiting_time_atl1)],
    'ATL2': [np.mean(travel_time_atl2), np.mean(waiting_time_atl2)],
    'RP': [np.mean(travel_time_random), np.mean(waiting_time_random)],
    'MAD4QN-PS': [np.mean(travel_time_mad4qn), np.mean(waiting_time_mad4qn)]
}

x = range(0, 6)
bar_width = 0.4

facecolors = ['green', 'darkblue', 'gray', 'red']
edgecolors = facecolors

for i, pair in enumerate(travel_time_histo2.values()):
    if i in (0, 1):
        plt.bar(x[i] - bar_width/2, pair[0], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
        plt.bar(x[i] + bar_width/2, pair[1], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.3)        
    elif i in (2, 3):
        plt.bar(x[i] - bar_width/2, pair[0], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8,
               )
        plt.bar(x[i] + bar_width/2, pair[1], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.3)        
    elif i == 4:
        plt.bar(x[i] - bar_width/2, pair[0], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8,
               label='Average travel time per vehicle')
        plt.bar(x[i] + bar_width/2, pair[1], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.3,
               label='Average waiting time per vehicle')        
    else:
        plt.bar(x[i] - bar_width/2, pair[0], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
        plt.bar(x[i] + bar_width/2, pair[1], bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.3)        
plt.xticks(range(0, 6), list(travel_time_histo2.keys()), fontsize=14)
# plt.xlabel('Method', fontsize=14)
plt.ylabel('Time [s]', fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=12)
plt.grid(axis='y')
plt.savefig("figures/travel_time.png", format='png')  
plt.show()

# %%
avg_speed_histo = {
    'FTTL2': np.mean(avg_speed_fttl2),
    'FTTL1': np.mean(avg_speed_fttl1),
    'ATL2': np.mean(avg_speed_atl2),
    'ATL1': np.mean(avg_speed_atl1),
    'RP': np.mean(avg_speed_random),
    'MAD4QN-PS': np.mean(avg_speed_mad4qn)
}

avg_speed_histo2 = {
    'FTTL1': np.mean(avg_speed_fttl1),
    'FTTL2': np.mean(avg_speed_fttl2),
    'ATL1': np.mean(avg_speed_atl1),
    'ATL2': np.mean(avg_speed_atl2),
    'RP': np.mean(avg_speed_random),
    'MAD4QN-PS': np.mean(avg_speed_mad4qn)
}

x = range(0, 6)
bar_width = 0.65

facecolors = ['green', 'chocolate', 'gray', 'red']
edgecolors = facecolors

for i, pair in enumerate(avg_speed_histo2.values()):
    if i in (0, 1):
        plt.bar(x[i], pair, bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
    elif i in (2, 3):
        plt.bar(x[i], pair, bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
    elif i == 4:
        plt.bar(x[i], pair, bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
    else:
        plt.bar(x[i], pair, bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
plt.xticks(range(0, 6), list(avg_speed_histo2.keys()), fontsize=14)
plt.ylabel('Speed [m/s]', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(axis='y')
plt.savefig("figures/avg_speed.png", format='png')  
plt.show()

# %%
collisions_histo = {
    'RP': np.mean(collisions_random),
    'MAD4QN-PS': np.mean(collisions_mad4qn)
}

x = [0, 0.25]
bar_width = 0.15

facecolors = ['green', 'darkgreen', 'gray', 'red']
edgecolors = facecolors

for i, pair in enumerate(collisions_histo.values()):
    if i == 0:
        plt.bar(x[i], pair*100, bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
    else:
        plt.bar(x[i], pair*100, bar_width, color=facecolors[1], edgecolor=edgecolors[1], alpha=0.8)
plt.xticks([0, 0.25], list(collisions_histo.keys()), fontsize=14)
plt.ylabel('Percentage [%]', fontsize=14)
plt.yticks(fontsize=14)
plt.grid(axis='y')
plt.savefig("figures/collisions.png", format='png')  
plt.show()
